# %%
import os
import json
import pandas as pd

# %%
# Set the path to your Spotify folder
folder_path = os.path.expanduser("~/Desktop/Spotify")

# %%
folder_path
# Out:
# 'C:\\Users\\Lenovo/Desktop/Spotify'

# %%
# Get all JSON files in the folder that match the naming pattern
json_files = sorted([
    f for f in os.listdir(folder_path)
    if f.startswith("Streaming_History_Audio_") and f.endswith(".json")
])

# %%
# Read and combine all JSON files
all_data = []
for file_name in json_files:
    file_path = os.path.join(folder_path, file_name)
    with open(file_path, 'r', encoding='utf-8') as f:
        data = json.load(f)
        all_data.extend(data)

# %%
# Convert to DataFrame
df = pd.DataFrame(all_data)

# %%
df
# Out:
#                           ts                                      platform  \
# 0       2019-03-08T01:47:46Z  Android-tablet OS 7.1.2 API 25 (motorola,  )
# 1       2019-03-08T01:47:46Z  Android-tablet OS 7.1.2 API 25 (motorola,  )
# 2       2019-03-08T01:47:47Z  Android-tablet OS 7.1.2 API 25 (motorola,  )
# 3       2019-03-08T01:47:56Z  Android-tablet OS 7.1.2 API 25 (motorola,  )
# 4       2019-03-08T01:51:55Z  Android-tablet OS 7.1.2 API 25 (motorola,  )
# ...                      ...                                           ...
# 241517  2025-05-18T21:36:14Z                                       windows
# 241518  2025-05-18T21:39:59Z                                       windows
# 241519  2025-05-18T21:44:45Z                                       windows
# 241520  2025-05-18T21:51:42Z                                       windows
# 241521  2025-05-18T22:08:55Z                                       android
#
#         ms_played conn_country                                  ip_addr  \
# 0            7227           IN                            103.241.45.61
# 1             774           IN                            103.241.45.61
# 2               0           IN                            103.241.45.61
# 3               0           IN                            103.241.45.61
# 4          211440           IN                            103.241.45.61
# ...           ...          ...                                      ...
# 241517     276125           US                             35.146.30.99
# 241518     224206           US                             35.146.30.99
# 241519     285624           US                             35.146.30.99
# 241520     416613           US                             35.146.30.99
# 241521          1           US  2603:8080:1ef0:6310:abba:200f:cf10:cd72
#
#                master_metadata_track_name master_metadata_album_artist_name  \
# 0                             Khuda Jaane                    Vishal-Shekhar
# 1       Pray For Me (with Kendrick Lamar)                        The Weeknd
# 2              Believer (feat. Lil Wayne)                   Imagine Dragons
# 3            Emiway-Samajh Mein Aaya Kya?                     Emiway Bantai
# 4       Pray For Me (with Kendrick Lamar)                        The Weeknd
# ...                                   ...                               ...
# 241517                       Aal Izz Well                   Swanand Kirkire
# 241518       Afghan Jalebi (Film Version)                            Pritam
# 241519                     Sanson Ki Mala              Rahat Fateh Ali Khan
# 241520                    Chaiyya Chaiyya                  Sukhwinder Singh
# 241521                Nashe Si Chadh Gayi                    Vishal-Shekhar
#
#                          master_metadata_album_album_name  \
# 0                                       Bachna Ae Haseeno
# 1       Black Panther The Album Music From And Inspire...
# 2                              Believer (feat. Lil Wayne)
# 3                            Emiway-Samajh Mein Aaya Kya?
# 4       Black Panther The Album Music From And Inspire...
# ...                                                   ...
# 241517                                           3 Idiots
# 241518                                            Phantom
# 241519                                     Sanson Ki Mala
# 241520                                             Dil Se
# 241521                                            Befikre
#
#                            spotify_track_uri episode_name  ... audiobook_uri  \
# 0       spotify:track:0gPgdRfB4jdGrlyXS0Vx78         None  ...          None
# 1       spotify:track:77UjLW8j5UAGAGVGhR5oUK         None  ...          None
# 2       spotify:track:2sU9EjevkrU9OkPZudvFNN         None  ...          None
# 3       spotify:track:7n8xH63Whw5spavIWScPIh         None  ...          None
# 4       spotify:track:77UjLW8j5UAGAGVGhR5oUK         None  ...          None
# ...                                      ...          ...  ...           ...
# 241517  spotify:track:4sZDyON3hp3bB9Y8uayqvT         None  ...          None
# 241518  spotify:track:1rEVydQSe04NJUqyyEyeEq         None  ...          None
# 241519  spotify:track:0kT0RwW83Yl0Vrym7moHAo         None  ...          None
# 241520  spotify:track:5H4rKylLnO8KrmdXTRhj5s         None  ...          None
# 241521  spotify:track:0biCSADTAblvLTLtJz4pXO         None  ...          None
#
#        audiobook_chapter_uri audiobook_chapter_title reason_start reason_end  \
# 0                       None                    None     clickrow    endplay
# 1                       None                    None     clickrow    endplay
# 2                       None                    None     clickrow    endplay
# 3                       None                    None     clickrow    endplay
# 4                       None                    None     clickrow  trackdone
# ...                      ...                     ...          ...        ...
# 241517                  None                    None    trackdone  trackdone
# 241518                  None                    None    trackdone  trackdone
# 241519                  None                    None    trackdone  trackdone
# 241520                  None                    None    trackdone  trackdone
# 241521                  None                    None       remote  trackdone
#
#        shuffle skipped offline  offline_timestamp  incognito_mode
# 0        False   False   False                NaN           False
# 1        False   False   False                NaN           False
# 2        False   False   False                NaN           False
# 3        False   False   False                NaN           False
# 4        False   False   False                NaN           False
# ...        ...     ...     ...                ...             ...
# 241517    True   False   False       1.747604e+09           False
# 241518    True   False   False       1.747604e+09           False
# 241519    True   False   False       1.747604e+09           False
# 241520    True   False   False       1.747605e+09           False
# 241521    True   False   False       1.747606e+09           False
#
# [241522 rows x 23 columns]

# %%
df.head(2)
# Out:
#                      ts                                      platform  \
# 0  2019-03-08T01:47:46Z  Android-tablet OS 7.1.2 API 25 (motorola,  )
# 1  2019-03-08T01:47:46Z  Android-tablet OS 7.1.2 API 25 (motorola,  )
#
#    ms_played conn_country        ip_addr         master_metadata_track_name  \
# 0       7227           IN  103.241.45.61                        Khuda Jaane
# 1        774           IN  103.241.45.61  Pray For Me (with Kendrick Lamar)
#
#   master_metadata_album_artist_name  \
# 0                    Vishal-Shekhar
# 1                        The Weeknd
#
#                     master_metadata_album_album_name  \
# 0                                  Bachna Ae Haseeno
# 1  Black Panther The Album Music From And Inspire...
#
#                       spotify_track_uri episode_name  ... audiobook_uri  \
# 0  spotify:track:0gPgdRfB4jdGrlyXS0Vx78         None  ...          None
# 1  spotify:track:77UjLW8j5UAGAGVGhR5oUK         None  ...          None
#
#   audiobook_chapter_uri audiobook_chapter_title reason_start reason_end  \
# 0                  None                    None     clickrow    endplay
# 1                  None                    None     clickrow    endplay
#
#   shuffle skipped offline  offline_timestamp  incognito_mode
# 0   False   False   False                NaN           False
# 1   False   False   False                NaN           False
#
# [2 rows x 23 columns]

# %%
vpn_corrections = {
    'SG': 'IN',  # Singapore ➝ India
    'FR': 'US',  # France ➝ United States
    'NL': 'US',  # Netherlands ➝ United States
    'GB': 'US',  # United Kingdom ➝ United States
    'JP': 'US'   # Japan ➝ United States
}

# Apply corrections to 'conn_country'
df['conn_country'] = df['conn_country'].replace(vpn_corrections)

# Re-map corrected 'conn_country' to full names
import pycountry
country_mapping = {country.alpha_2: country.name for country in pycountry.countries}
df['conn_country_full'] = df['conn_country'].map(country_mapping)

# %%
df['conn_country_full'].unique()
# Out:
# array(['India', nan, 'United States', 'Qatar'], dtype=object)

# %%
df.head()
# Out:
#                      ts                                      platform  \
# 0  2019-03-08T01:47:46Z  Android-tablet OS 7.1.2 API 25 (motorola,  )
# 1  2019-03-08T01:47:46Z  Android-tablet OS 7.1.2 API 25 (motorola,  )
# 2  2019-03-08T01:47:47Z  Android-tablet OS 7.1.2 API 25 (motorola,  )
# 3  2019-03-08T01:47:56Z  Android-tablet OS 7.1.2 API 25 (motorola,  )
# 4  2019-03-08T01:51:55Z  Android-tablet OS 7.1.2 API 25 (motorola,  )
#
#    ms_played conn_country        ip_addr         master_metadata_track_name  \
# 0       7227           IN  103.241.45.61                        Khuda Jaane
# 1        774           IN  103.241.45.61  Pray For Me (with Kendrick Lamar)
# 2          0           IN  103.241.45.61         Believer (feat. Lil Wayne)
# 3          0           IN  103.241.45.61       Emiway-Samajh Mein Aaya Kya?
# 4     211440           IN  103.241.45.61  Pray For Me (with Kendrick Lamar)
#
#   master_metadata_album_artist_name  \
# 0                    Vishal-Shekhar
# 1                        The Weeknd
# 2                   Imagine Dragons
# 3                     Emiway Bantai
# 4                        The Weeknd
#
#                     master_metadata_album_album_name  \
# 0                                  Bachna Ae Haseeno
# 1  Black Panther The Album Music From And Inspire...
# 2                         Believer (feat. Lil Wayne)
# 3                       Emiway-Samajh Mein Aaya Kya?
# 4  Black Panther The Album Music From And Inspire...
#
#                       spotify_track_uri episode_name  ...  \
# 0  spotify:track:0gPgdRfB4jdGrlyXS0Vx78         None  ...
# 1  spotify:track:77UjLW8j5UAGAGVGhR5oUK         None  ...
# 2  spotify:track:2sU9EjevkrU9OkPZudvFNN         None  ...
# 3  spotify:track:7n8xH63Whw5spavIWScPIh         None  ...
# 4  spotify:track:77UjLW8j5UAGAGVGhR5oUK         None  ...
#
#   audiobook_chapter_uri audiobook_chapter_title reason_start reason_end  \
# 0                  None                    None     clickrow    endplay
# 1                  None                    None     clickrow    endplay
# 2                  None                    None     clickrow    endplay
# 3                  None                    None     clickrow    endplay
# 4                  None                    None     clickrow  trackdone
#
#   shuffle skipped offline offline_timestamp  incognito_mode  conn_country_full
# 0   False   False   False               NaN           False              India
# 1   False   False   False               NaN           False              India
# 2   False   False   False               NaN           False              India
# 3   False   False   False               NaN           False              India
# 4   False   False   False               NaN           False              India
#
# [5 rows x 24 columns]

# %%
df.tail()
# Out:
#                           ts platform  ms_played conn_country  \
# 241517  2025-05-18T21:36:14Z  windows     276125           US
# 241518  2025-05-18T21:39:59Z  windows     224206           US
# 241519  2025-05-18T21:44:45Z  windows     285624           US
# 241520  2025-05-18T21:51:42Z  windows     416613           US
# 241521  2025-05-18T22:08:55Z  android          1           US
#
#                                         ip_addr    master_metadata_track_name  \
# 241517                             35.146.30.99                  Aal Izz Well
# 241518                             35.146.30.99  Afghan Jalebi (Film Version)
# 241519                             35.146.30.99                Sanson Ki Mala
# 241520                             35.146.30.99               Chaiyya Chaiyya
# 241521  2603:8080:1ef0:6310:abba:200f:cf10:cd72           Nashe Si Chadh Gayi
#
#        master_metadata_album_artist_name master_metadata_album_album_name  \
# 241517                   Swanand Kirkire                         3 Idiots
# 241518                            Pritam                          Phantom
# 241519              Rahat Fateh Ali Khan                   Sanson Ki Mala
# 241520                  Sukhwinder Singh                           Dil Se
# 241521                    Vishal-Shekhar                          Befikre
#
#                            spotify_track_uri episode_name  ...  \
# 241517  spotify:track:4sZDyON3hp3bB9Y8uayqvT         None  ...
# 241518  spotify:track:1rEVydQSe04NJUqyyEyeEq         None  ...
# 241519  spotify:track:0kT0RwW83Yl0Vrym7moHAo         None  ...
# 241520  spotify:track:5H4rKylLnO8KrmdXTRhj5s         None  ...
# 241521  spotify:track:0biCSADTAblvLTLtJz4pXO         None  ...
#
#        audiobook_chapter_uri audiobook_chapter_title reason_start reason_end  \
# 241517                  None                    None    trackdone  trackdone
# 241518                  None                    None    trackdone  trackdone
# 241519                  None                    None    trackdone  trackdone
# 241520                  None                    None    trackdone  trackdone
# 241521                  None                    None       remote  trackdone
#
#        shuffle skipped offline offline_timestamp  incognito_mode  \
# 241517    True   False   False      1.747604e+09           False
# 241518    True   False   False      1.747604e+09           False
# 241519    True   False   False      1.747604e+09           False
# 241520    True   False   False      1.747605e+09           False
# 241521    True   False   False      1.747606e+09           False
#
#         conn_country_full
# 241517      United States
# 241518      United States
# 241519      United States
# 241520      United States
# 241521      United States
#
# [5 rows x 24 columns]

# %%
import pandas as pd
import pytz

# Ensure ts is parsed as timezone-aware UTC
df['ts'] = pd.to_datetime(df['ts'], utc=True)

# Cutoff for NaN conn_country fallback
cutoff = pd.Timestamp('2024-08-04', tz='UTC')

# Split by group and localize separately
dfs = []

# India
mask_in = df['conn_country'] == 'IN'
df_in = df[mask_in].copy()
df_in['ts_local'] = df_in['ts'].dt.tz_convert('Asia/Kolkata')
dfs.append(df_in)

# US
mask_us = df['conn_country'] == 'US'
df_us = df[mask_us].copy()
df_us['ts_local'] = df_us['ts'].dt.tz_convert('America/New_York')
dfs.append(df_us)

# Qatar
mask_qa = df['conn_country'] == 'QA'
df_qa = df[mask_qa].copy()
df_qa['ts_local'] = df_qa['ts'].dt.tz_convert('Asia/Qatar')
dfs.append(df_qa)

# NaN fallback (US after Aug 4, 2024)
mask_nan_us = df['conn_country'].isna() & (df['ts'] >= cutoff)
df_nan_us = df[mask_nan_us].copy()
df_nan_us['ts_local'] = df_nan_us['ts'].dt.tz_convert('America/New_York')
dfs.append(df_nan_us)

# NaN fallback (India before Aug 4, 2024)
mask_nan_in = df['conn_country'].isna() & (df['ts'] < cutoff)
df_nan_in = df[mask_nan_in].copy()
df_nan_in['ts_local'] = df_nan_in['ts'].dt.tz_convert('Asia/Kolkata')
dfs.append(df_nan_in)

# %%
# Combine all
df = pd.concat(dfs).sort_index()

# %%
df.tail()
# Out:
#                               ts platform  ms_played conn_country  \
# 241517 2025-05-18 21:36:14+00:00  windows     276125           US
# 241518 2025-05-18 21:39:59+00:00  windows     224206           US
# 241519 2025-05-18 21:44:45+00:00  windows     285624           US
# 241520 2025-05-18 21:51:42+00:00  windows     416613           US
# 241521 2025-05-18 22:08:55+00:00  android          1           US
#
#                                         ip_addr    master_metadata_track_name  \
# 241517                             35.146.30.99                  Aal Izz Well
# 241518                             35.146.30.99  Afghan Jalebi (Film Version)
# 241519                             35.146.30.99                Sanson Ki Mala
# 241520                             35.146.30.99               Chaiyya Chaiyya
# 241521  2603:8080:1ef0:6310:abba:200f:cf10:cd72           Nashe Si Chadh Gayi
#
#        master_metadata_album_artist_name master_metadata_album_album_name  \
# 241517                   Swanand Kirkire                         3 Idiots
# 241518                            Pritam                          Phantom
# 241519              Rahat Fateh Ali Khan                   Sanson Ki Mala
# 241520                  Sukhwinder Singh                           Dil Se
# 241521                    Vishal-Shekhar                          Befikre
#
#                            spotify_track_uri episode_name  ...  \
# 241517  spotify:track:4sZDyON3hp3bB9Y8uayqvT         None  ...
# 241518  spotify:track:1rEVydQSe04NJUqyyEyeEq         None  ...
# 241519  spotify:track:0kT0RwW83Yl0Vrym7moHAo         None  ...
# 241520  spotify:track:5H4rKylLnO8KrmdXTRhj5s         None  ...
# 241521  spotify:track:0biCSADTAblvLTLtJz4pXO         None  ...
#
#        audiobook_chapter_title reason_start reason_end shuffle skipped  \
# 241517                    None    trackdone  trackdone    True   False
# 241518                    None    trackdone  trackdone    True   False
# 241519                    None    trackdone  trackdone    True   False
# 241520                    None    trackdone  trackdone    True   False
# 241521                    None       remote  trackdone    True   False
#
#        offline offline_timestamp incognito_mode  conn_country_full  \
# 241517   False      1.747604e+09          False      United States
# 241518   False      1.747604e+09          False      United States
# 241519   False      1.747604e+09          False      United States
# 241520   False      1.747605e+09          False      United States
# 241521   False      1.747606e+09          False      United States
#
#                          ts_local
# 241517  2025-05-18 17:36:14-04:00
# 241518  2025-05-18 17:39:59-04:00
# 241519  2025-05-18 17:44:45-04:00
# 241520  2025-05-18 17:51:42-04:00
# 241521  2025-05-18 18:08:55-04:00
#
# [5 rows x 25 columns]

# %%
import re

def clean_platform(value):
    if pd.isna(value):
        return 'Unknown'

    val = str(value).lower()

    if re.search(r'android', val):
        return 'Android'
    elif re.search(r'windows', val):
        return 'Windows'
    elif re.search(r'ios|iphone|ipad|mac|darwin', val):
        return 'iOS'
    elif re.search(r'google cast|chromecast|cast_', val):
        return 'Google Cast'
    else:
        return 'Other'
    
# Apply to platform column
df['platform_clean'] = df['platform'].apply(clean_platform)

# %%
df['platform_clean'].unique()
# Out:
# array(['Android', 'Windows', 'Google Cast', 'Other', 'iOS'], dtype=object)

# %%
df.iloc[0]
# Out:
# ts                                                      2019-03-08 01:47:46+00:00
# platform                             Android-tablet OS 7.1.2 API 25 (motorola,  )
# ms_played                                                                    7227
# conn_country                                                                   IN
# ip_addr                                                             103.241.45.61
# master_metadata_track_name                                            Khuda Jaane
# master_metadata_album_artist_name                                  Vishal-Shekhar
# master_metadata_album_album_name                                Bachna Ae Haseeno
# spotify_track_uri                            spotify:track:0gPgdRfB4jdGrlyXS0Vx78
# episode_name                                                                 None
# episode_show_name                                                            None
# spotify_episode_uri                                                          None
# audiobook_title                                                              None
# audiobook_uri                                                                None
# audiobook_chapter_uri                                                        None
# audiobook_chapter_title                                                      None
# reason_start                                                             clickrow
# reason_end                                                                endplay
# shuffle                                                                     False
# skipped                                                                     False
# offline                                                                     False
# offline_timestamp                                                             NaN
# incognito_mode                                                              False
# conn_country_full                                                           India
# ts_local                                                2019-03-08 07:17:46+05:30
# platform_clean                                                            Android
# Name: 0, dtype: object

# %%
df.columns
# Out:
# Index(['ts', 'platform', 'ms_played', 'conn_country', 'ip_addr',
#        'master_metadata_track_name', 'master_metadata_album_artist_name',
#        'master_metadata_album_album_name', 'spotify_track_uri', 'episode_name',
#        'episode_show_name', 'spotify_episode_uri', 'audiobook_title',
#        'audiobook_uri', 'audiobook_chapter_uri', 'audiobook_chapter_title',
#        'reason_start', 'reason_end', 'shuffle', 'skipped', 'offline',
#        'offline_timestamp', 'incognito_mode', 'conn_country_full', 'ts_local',
#        'platform_clean'],
#       dtype='object')

# %%
df_clean = df[['ms_played', 'conn_country_full','master_metadata_track_name','master_metadata_album_artist_name','master_metadata_album_album_name','reason_start','reason_end','shuffle','skipped', 'offline','incognito_mode', 'conn_country_full', 'ts_local',
       'platform_clean']]

# %%
df_clean.tail()
# Out:
#         ms_played conn_country_full    master_metadata_track_name  \
# 241517     276125     United States                  Aal Izz Well
# 241518     224206     United States  Afghan Jalebi (Film Version)
# 241519     285624     United States                Sanson Ki Mala
# 241520     416613     United States               Chaiyya Chaiyya
# 241521          1     United States           Nashe Si Chadh Gayi
#
#        master_metadata_album_artist_name master_metadata_album_album_name  \
# 241517                   Swanand Kirkire                         3 Idiots
# 241518                            Pritam                          Phantom
# 241519              Rahat Fateh Ali Khan                   Sanson Ki Mala
# 241520                  Sukhwinder Singh                           Dil Se
# 241521                    Vishal-Shekhar                          Befikre
#
#        reason_start reason_end  shuffle  skipped  offline  incognito_mode  \
# 241517    trackdone  trackdone     True    False    False           False
# 241518    trackdone  trackdone     True    False    False           False
# 241519    trackdone  trackdone     True    False    False           False
# 241520    trackdone  trackdone     True    False    False           False
# 241521       remote  trackdone     True    False    False           False
#
#        conn_country_full                   ts_local platform_clean
# 241517     United States  2025-05-18 17:36:14-04:00        Windows
# 241518     United States  2025-05-18 17:39:59-04:00        Windows
# 241519     United States  2025-05-18 17:44:45-04:00        Windows
# 241520     United States  2025-05-18 17:51:42-04:00        Windows
# 241521     United States  2025-05-18 18:08:55-04:00        Android

# %%
df_clean.to_csv("df_clean.csv", index=False)

# %%
df_clean['ts_local'].dtype
# Out:
# dtype('O')

# %%
#Convert ts_local to datetime
df_clean['ts_local'] = pd.to_datetime(df_clean['ts_local'])

#Extract components
df_clean['Hour'] = df_clean['ts_local'].dt.hour
df_clean['Minute'] = df_clean['ts_local'].dt.minute
df_clean['Second'] = df_clean['ts_local'].dt.second
df_clean['HH:MM:SS'] = df_clean['ts_local'].dt.strftime('%H:%M:%S')

df_clean['Date'] = df_clean['ts_local'].dt.date
df_clean['Day_Name'] = df_clean['ts_local'].dt.day_name()
df_clean['Month'] = df_clean['ts_local'].dt.month
df_clean['Month_Name'] = df_clean['ts_local'].dt.month_name()
df_clean['Year'] = df_clean['ts_local'].dt.year
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[62], line 2
#       1 #Convert ts_local to datetime
# ----> 2 df_clean['ts_local'] = pd.to_datetime(df_clean['ts_local'])
#       4 #Extract components
#       5 df_clean['Hour'] = df_clean['ts_local'].dt.hour
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:1067, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1065         result = arg.map(cache_array)
#    1066     else:
# -> 1067         values = convert_listlike(arg._values, format)
#    1068         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1069 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:435, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     432 if format is not None and format != "mixed":
#     433     return _array_strptime_with_fallback(arg, name, utc, format, exact, errors)
# --> 435 result, tz_parsed = objects_to_datetime64(
#     436     arg,
#     437     dayfirst=dayfirst,
#     438     yearfirst=yearfirst,
#     439     utc=utc,
#     440     errors=errors,
#     441     allow_object=True,
#     442 )
#     444 if tz_parsed is not None:
#     445     # We can take a shortcut since the datetime64 numpy array
#     446     # is in UTC
#     447     out_unit = np.datetime_data(result.dtype)[0]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\arrays\datetimes.py:2398, in objects_to_datetime64(data, dayfirst, yearfirst, utc, errors, allow_object, out_unit)
#    2395 # if str-dtype, convert
#    2396 data = np.asarray(data, dtype=np.object_)
# -> 2398 result, tz_parsed = tslib.array_to_datetime(
#    2399     data,
#    2400     errors=errors,
#    2401     utc=utc,
#    2402     dayfirst=dayfirst,
#    2403     yearfirst=yearfirst,
#    2404     creso=abbrev_to_npy_unit(out_unit),
#    2405 )
#    2407 if tz_parsed is not None:
#    2408     # We can take a shortcut since the datetime64 numpy array
#    2409     #  is in UTC
#    2410     return result, tz_parsed
#
# File tslib.pyx:414, in pandas._libs.tslib.array_to_datetime()
#
# File tslib.pyx:596, in pandas._libs.tslib.array_to_datetime()
#
# File tslib.pyx:504, in pandas._libs.tslib.array_to_datetime()
#
# File strptime.pyx:285, in pandas._libs.tslibs.strptime.DatetimeParseState.process_datetime()
#
# ValueError: Tz-aware datetime.datetime cannot be converted to datetime64 unless utc=True, at position 168886
